# %% [markdown]
# <a href="https://colab.research.google.com/github/mariyarahman411-crypto/Google-Colab-Notebook/blob/main/python_basics_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
5+3
# Out:
# 8

# %%
2==2
# Out:
# True

# %%
a=10
b=10
print(a+b)
# Out:
# 20

# %%
a=30
b=20
c=a-b
print(c)
# Out:
# 10

# %%
x=5
print(x)
x=0.5
print(x)
x="Mariya"
print("Mariya")
# Out:
# 5
# 0.5
# Mariya

# %%
birth_year=input("enter your brithday year:")
age=2026-int (birth_year)
print("you are is:", age)
# Out:
# enter your brithday year:2005
# you are is: 21

# %%
a=50
b=25.5
print(a)
print(b)
print( int(a/b))
print(a+b)
type(b)
# Out:
# 50
# 25.5
# 1
# 75.5
# float

# %%
a=1
type(a)
print(type(a))
b=1.0
type(type(b))
c='Mariya'
type("c")
d=True
type(d)
print(a)
print(c)
# Out:
# <class 'int'>
# 1
# Mariya

# %%
a,b,3,3.88,'Mariya',False
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
2!=2
# Out:
# False

# %%
a=5
a
# Out:
# 5

# %%
a-=2
a
# Out:
# -1

# %%
a++3
a
# Out:
# -1

# %%
++a
# Out:
# -1

# %%
a+=2
a
# Out:
# 1

# %%
a=2
a+=2
a
# Out:
# 4

# %%
2==2 and 3==3
# Out:
# True

# %%
2==2 and 3==5
# Out:
# False

# %%
2==2 or 3==6
2==1 and 3==6
# Out:
# False

# %%
a='Bangladesh'
b='desh'
print(b in a)
print(a in b)
# Out:
# True
# False

# %%
a=1
b=1
print(b is a)
print(a is b)
# Out:
# True
# True

# %%
b="Bangladesh is\\mother land\\'i love my motherland' a vary beautifull cuntry"
print(b)
# Out:
# Bangladesh is\mother land\'i love my motherland' a vary beautifull cuntry

# %% [markdown]
# n="Mariya"
# s="Rahman"
# print

# %%
n="Mariya"
s="Rahman"
print(n + " " + s)
# Out:
# Mariya Rahman

# %%
w="Bangladesh"
print(w[0])
print(w[1])
print(w[2])
print(w[3])
print(w[-0])
print(w[::-1])
print(w[:-2])
print(w[-3])
# Out:
# B
# a
# n
# g
# B
# hsedalgnaB
# Banglade
# e

# %%
name="Mariya rahman"
age="22 "
univirsity=" Prime Univirsity"
